# %% [markdown]
# # RQ 2. How much language does the key child produce (utterances and words)?

# %%
import sys
sys.path.append('/home/nele_pauline_suffo/projects/naturalistic-social-analysis/src')

import pandas as pd
import numpy as np
import sqlite3
import re
from constants import DataPaths, ResearchQuestions
from rq_02_queries import map_vocalizations_to_segments

# %%
segments_df = pd.read_csv(ResearchQuestions.INTERACTION_SEGMENTS_CSV)
age_df = pd.read_csv("/home/nele_pauline_suffo/ProcessedData/age_group.csv")

# %%
segments_df.head()
# Out:
#    video_id                              video_name           category  \
# 0         1  quantex_at_home_id254922_2022_04_12_01        Interacting
# 1         1  quantex_at_home_id254922_2022_04_12_01  Co-present Silent
# 2         1  quantex_at_home_id254922_2022_04_12_01              Alone
# 3         1  quantex_at_home_id254922_2022_04_12_01        Interacting
# 4         1  quantex_at_home_id254922_2022_04_12_01              Alone
#
#    segment_start  segment_end  start_time_sec  end_time_sec  duration_sec
# 0             40          220        1.333333      7.333333      6.000000
# 1            230          590        7.666667     19.666667     12.000000
# 2            600         5350       20.000000    178.333333    158.333333
# 3           5360         6130      178.666667    204.333333     25.666667
# 4           6140         6400      204.666667    213.333333      8.666667

# %%
utterance_data = map_vocalizations_to_segments()

utterance_data = pd.DataFrame(mapped_rows)

# %%
utterance_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ResearchQuestions.head()
#
# NameError: name 'ResearchQuestions' is not defined
