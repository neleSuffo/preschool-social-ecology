# %% [markdown]
# # 4. Are children more frequently in the presence of adults compared to other children?

# %%
import sys
from pathlib import Path

# Get the src directory (2 levels up from current notebook location)
src_path = Path(__file__).parent.parent.parent if '__file__' in globals() else Path.cwd().parent.parent
sys.path.append(str(src_path))

from rq_04_queries import extract_presence_counts
from constants import ResearchQuestions

# %%
counts_df = extract_presence_counts()
# save df to csv
counts_df.to_csv(ResearchQuestions.PRESENCE_COUNTS_CSV, index=False)
